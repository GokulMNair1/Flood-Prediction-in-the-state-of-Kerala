# %%
import pickle
with open('model.pkl','rb') as file:
    lr=pickle.load(file)

# %%
import tkinter as tk
from tkinter import messagebox, ttk
from tkinter import *
import numpy as np

win = Tk()
win.geometry('2000x900')
win.configure(bg='lavender')


def change_color():
    current_color = title.cget("foreground")
    next_color = "black" if current_color == "black" else "black"
    title.config(foreground=next_color)
    win.after(1000, change_color)

win.title('Flood prediction in the state of Kerala') 
title= Label(win,text="Flood prediction in the state of Kerala",bg="lavender",fg="white",font=("Times",35,"bold"),justify=CENTER)
title.grid(row=0,column=0,columnspan=5,padx=20)
change_color()

space= Label(win,text="          ",anchor=CENTER,bg="lavender",fg="black")
space.grid(row=1,column=0,sticky='W',columnspan=5,pady=20)


varjan=tk.StringVar()
varfeb=tk.StringVar()
varmar=tk.StringVar()
varapr=tk.StringVar()
varmay=tk.StringVar()
varjun=tk.StringVar()
varjul=tk.StringVar()
varaug=tk.StringVar()
varsep=tk.StringVar()
varoct=tk.StringVar()
varnov=tk.StringVar()
vardec=tk.StringVar()
varPredict=tk.StringVar()

varjan.set("")
varfeb.set("")
varmar.set("")
varapr.set("")
varmay.set("")
varjun.set("")
varjul.set("")
varaug.set("")
varsep.set("")
varoct.set("")
varnov.set("")
vardec.set("")
varPredict.set("")

import pandas as pd
def action():
    global DF
    import pandas as pd
    
    DF = pd.DataFrame(columns=['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'])
    
    jan=float(varjan.get())
    DF.loc[0,'JAN']=jan
             
    feb=float(varfeb.get())
    DF.loc[0,'FEB']= feb
    
    mar=float(varmar.get())
    DF.loc[0,'MAR']= mar
    
    apr=float(varapr.get())
    DF.loc[0,'APR']= apr
    
    
    may=float(varmay.get())
    DF.loc[0,'MAY']= may
    
    
    jun=float(varjun.get())
    DF.loc[0,'JUN']= jun
    
    
    jul=float(varjul.get())
    DF.loc[0,'JUL']= jul
    
    
    aug=float(varaug.get())
    DF.loc[0,'AUG']= aug
    
    
    sep=float(varsep.get())
    DF.loc[0,'SEP']= sep
    
    
    octb=float(varoct.get())
    DF.loc[0,'OCT']= octb
    
    
    nov=float(varnov.get())
    DF.loc[0,'NOV']= nov
    
    
    dec=float(vardec.get())
    DF.loc[0,'DEC']= dec
    
        
    value=DF.loc[:,:]
    output=lr.predict(value)[0]
    if output==1:
        varPredict.set("Flood will occur")
    else:
        varPredict.set("Flood will not occur")
    
    t.insert('1.0',text)

def validate():
    value=varjan.get()
    value1=varfeb.get()
    value2=varmar.get()
    value3=varapr.get()
    value4=varmay.get()
    value5=varjun.get()
    value6=varjul.get()
    value7=varaug.get()
    value8=varsep.get()
    value9=varoct.get()
    value10=varnov.get()
    value11=vardec.get()
    
    
    for i in value:
        if i=='.':
            value=value.replace('.','')
    for i in value1:
        if i=='.':
            value1=value1.replace('.','')
    for i in value2:
        if i=='.':
            value2=value2.replace('.','')
    for i in value3:
        if i=='.':
            value3=value3.replace('.','')
    for i in value4:
        if i=='.':
            value4=value4.replace('.','')
    for i in value5:
        if i=='.':
            value5=value5.replace('.','')
    for i in value6:
        if i=='.':
            value6=value6.replace('.','')
    for i in value7:
        if i=='.':
            value7=value7.replace('.','')
    for i in value8:
        if i=='.':
            value8=value8.replace('.','')
    for i in value9:
        if i=='.':
            value9=value9.replace('.','')
    for i in value10:
        if i=='.':
            value10=value10.replace('.','')
    for i in value11:
        if i=='.':
            value11=value11.replace('.','')        
    
    
    if value.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in January Field")
        if res == 1:
            varjan.set("")
    elif float(varjan.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in January Field")
        if res == 1:
            varjan.set("")
    elif float(varjan.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in January Field")
        if res == 1:
            varjan.set("")
    
    elif value1.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in February Field")
        if res == 1:
            varfeb.set("")
    elif float(varfeb.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in February Field")
        if res == 1:
            varfeb.set("")
    elif float(varfeb.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in February Field")
        if res == 1:
            varfeb.set("")
            
    elif value2.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in March Field")
        if res == 1:
            varmar.set("")
    elif float(varmar.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in March Field")
        if res == 1:
            varmar.set("")
    elif float(varmar.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in March Field")
        if res == 1:
            varmar.set("")
            
    elif value3.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in April Field")
        if res == 1:
            varapr.set("")
    elif float(varapr.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in April Field")
        if res == 1:
            varapr.set("")
    elif float(varapr.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in April Field")
        if res == 1:
            varapr.set("")
            
    elif value4.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in May Field")
        if res == 1:
            varmay.set("")
    elif float(varmay.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in May Field")
        if res == 1:
            varmay.set("")
    elif float(varmay.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in May Field")
        if res == 1:
            varmay.set("")
            
    elif value5.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in June Field")
        if res == 1:
            varjun.set("")
    elif float(varjun.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in June Field")
        if res == 1:
            varjun.set("")
    elif float(varjun.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in June Field")
        if res == 1:
            varjun.set("")
       
    elif value6.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in July Field")
        if res == 1:
            varjul.set("")
    elif float(varjul.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in July Field")
        if res == 1:
            varjul.set("")
    elif float(varjul.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in July Field")
        if res == 1:
            varjul.set("")
           
    elif value7.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in August Field")
        if res == 1:
            varaug.set("")
    elif float(varaug.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in August Field")
        if res == 1:
            varaug.set("")
    elif float(varaug.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in August Field")
        if res == 1:
            varaug.set("")
         
    elif value8.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in September Field")
        if res == 1:
            varsep.set("")
    elif float(varsep.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in September Field")
        if res == 1:
            varsep.set("")
    elif float(varsep.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in September Field")
        if res == 1:
            varsep.set("")
    
    elif value9.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in October Field")
        if res == 1:
            varoct.set("")
    elif float(varoct.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in October Field")
        if res == 1:
            varoct.set("")
    elif float(varoct.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in October Field")
        if res == 1:
            varoct.set("")
    
    elif value10.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in November Field")
        if res == 1:
            varnov.set("")
    elif float(varnov.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in November Field")
        if res == 1:
            varnov.set("")
    elif float(varnov.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in November Field")
        if res == 1:
            varnov.set("")
    
    elif value11.isdigit()!=True:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in December Field")
        if res == 1:
            vardec.set("")
    elif float(vardec.get())<0:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in December Field")
        if res == 1:
            vardec.set("")
    elif float(vardec.get())>2000:
        res=messagebox.askretrycancel("Error","Enter a value between the range 0 to 2000 range in December Field")
        if res == 1:
            vardec.set("")
            
    
    
    
    else:
        action()
    
    
        
def reset():
    varjan.set("")
    varfeb.set("")
    varmar.set("")
    varapr.set("")
    varmay.set("")
    varjun.set("")
    varjul.set("")
    varaug.set("")
    varsep.set("")
    varoct.set("")
    varnov.set("")
    vardec.set("")
    varPredict.set("")
    
    
JAN=Label(win,text="JANUARY (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
JAN.grid(row=2,column=0,sticky=W,padx=20,pady=5)
JAN_box=Entry(win,width=10,textvariable=varjan,bd=8,font=("Times",12,"bold"))
JAN_box.grid(row=2,column=1,sticky=W,padx=25,pady=8)


FEB=Label(win,text="FEBRUARY (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
FEB.grid(row=4,column=0,sticky=W,padx=20,pady=5)
FEB_box=Entry(win,width=10,textvariable=varfeb,bd=8,font=("Times",12,"bold"))
FEB_box.grid(row=4,column=1,sticky=W,padx=25,pady=8)


MAR=Label(win,text="MARCH (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
MAR.grid(row=6,column=0,sticky=W,padx=20,pady=5)
MAR_box=Entry(win,width=10,textvariable=varmar,bd=8,font=("Times",12,"bold"))
MAR_box.grid(row=6,column=1,sticky=W,padx=25,pady=8)


APR=Label(win,text="APRIL (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
APR.grid(row=8,column=0,sticky=W,padx=20,pady=5)
APR_box=Entry(win,width=10,textvariable=varapr,bd=8,font=("Times",12,"bold"))
APR_box.grid(row=8,column=1,sticky=W,padx=25,pady=8)


MAY=Label(win,text="MAY (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
MAY.grid(row=10,column=0,sticky=W,padx=20,pady=5)
MAY_box=Entry(win,width=10,textvariable=varmay,bd=8,font=("Times",12,"bold"))
MAY_box.grid(row=10,column=1,sticky=W,padx=25,pady=8)


JUN=Label(win,text="JUNE (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
JUN.grid(row=12,column=0,sticky=W,padx=20,pady=5)
JUN_box=Entry(win,width=10,textvariable=varjun,bd=8,font=("Times",12,"bold"))
JUN_box.grid(row=12,column=1,sticky=W,padx=25,pady=8)


JUL=Label(win,text="JULY (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
JUL.grid(row=2,column=3,sticky=W,padx=20,pady=5)
JUL_box=Entry(win,width=10,textvariable=varjul,bd=8,font=("Times",12,"bold"))
JUL_box.grid(row=2,column=4,sticky=W,padx=25,pady=8)


AUG=Label(win,text="AUGUST (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
AUG.grid(row=4,column=3,sticky=W,padx=20,pady=5)
AUG_box=Entry(win,width=10,textvariable=varaug,bd=8,font=("Times",12,"bold"))
AUG_box.grid(row=4,column=4,sticky=W,padx=25,pady=8)


SEP=Label(win,text="SEPTEMBER (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
SEP.grid(row=6,column=3,sticky=W,padx=20,pady=5)
SEP_box=Entry(win,width=10,textvariable=varsep,bd=8,font=("Times",12,"bold"))
SEP_box.grid(row=6,column=4,sticky=W,padx=25,pady=8)


OCT=Label(win,text="OCTOBER (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
OCT.grid(row=8,column=3,sticky=W,padx=20,pady=5)
OCT_box=Entry(win,width=10,textvariable=varoct,bd=8,font=("Times",12,"bold"))
OCT_box.grid(row=8,column=4,sticky=W,padx=25,pady=8)

NOV=Label(win,text="NOVEMBER (Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
NOV.grid(row=10,column=3,sticky=W,padx=20,pady=5)
NOV_box=Entry(win,width=10,textvariable=varnov,bd=8,font=("Times",12,"bold"))
NOV_box.grid(row=10,column=4,sticky=W,padx=25,pady=8)


DEC=Label(win,text="DECEMBER(Any int or float number can be entered)",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
DEC.grid(row=12,column=3,sticky=W,padx=20,pady=5)
DEC_box=Entry(win,width=10,textvariable=vardec,bd=8,font=("Times",12,"bold"))
DEC_box.grid(row=12,column=4,sticky=W,padx=25,pady=8)



Pred=Label(win,text="Result",anchor=W,bg="lavender",fg="black",font=("Times",15,"bold"),height=2)
Pred.grid(row=18,column=2,sticky=W,padx=25,pady=9)

Pred_entrybox=Entry(win,width=20,textvariable=varPredict,bd=8,font=("Times",12,"bold"))
Pred_entrybox.grid(row=18,column=3,sticky=W)

space1= Label(win,text="          ",anchor=CENTER,bg="lavender",fg="black")
space1.grid(row=16,column=0,sticky='W',columnspan=5,pady=15)


Predict=Button(win,text="SUBMIT",command=validate,anchor=CENTER,fg="black",bg="#DFA90D",font=("Times",15,"bold"),relief="raised",bd=8,width=15)
Predict.grid(row=16,column=1,sticky=W,columnspan=2,padx=25,pady=10)

Reset=Button(win,text="Reset",command=reset,anchor= CENTER,bg="#DFA90D",fg="black",font=("Times",15,"bold"),relief="raised",bd=8,width=15)
Reset.grid(row=16,column=3,sticky=W,columnspan=2,padx=25,pady=10)

win.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-3ede01280fe3>", line 328, in validate
#     action()
#   File "<ipython-input-4-3ede01280fe3>", line 113, in action
#     t.insert('1.0',text)
# NameError: name 't' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-3ede01280fe3>", line 328, in validate
#     action()
#   File "<ipython-input-4-3ede01280fe3>", line 113, in action
#     t.insert('1.0',text)
# NameError: name 't' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# ...
